# %%
import joblib
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
xt, yt, mt = joblib.load('/content/drive/MyDrive/Medal/ultrasound/BCFPP.jlb')

# %%
from tqdm import tqdm_notebook as tqdm

for i, x in tqdm(enumerate(xt)):
  if yt[i] == 0:
    cv2.imwrite('/content/drive/MyDrive/Medal/ultrasound/extracted/0_cancer/' + str(i) + '.jpg', x)
  elif yt[i] == 1:
    cv2.imwrite('/content/drive/MyDrive/Medal/ultrasound/extracted/1_benign/' + str(i) + '.jpg', x)
  else:
    cv2.imwrite('/content/drive/MyDrive/Medal/ultrasound/extracted/2_normal/' + str(i) + '.jpg', x)
# Out:
# <ipython-input-17-21fc48ab1470>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, x in tqdm(enumerate(xt)):
# 0it [00:00, ?it/s]
